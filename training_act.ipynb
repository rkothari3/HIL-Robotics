# %% [markdown]
# <a href="https://colab.research.google.com/github/rkothari3/HIL-Robotics/blob/main/training_act.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# !python lerobot/src/lerobot/scripts/train.py \
  --dataset.repo_id=rkothari3/il_gym_pickup \
  --policy.type=act \
  --output_dir=outputs/train/il_sim_test0 \
  --job_name=il_sim_test \
  --policy.device=cuda \
  --policy.push_to_hub=false
# Out:
# fatal: destination path 'lerobot' already exists and is not an empty directory.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<4.2.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.1.1)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.35.2)
# Requirement already satisfied: huggingface-hub<0.36.0,>=0.34.2 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.35.3)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (1.12.0)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (80.9.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.1.3)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.8.1)
# Requirement already satisfied: opencv-python-headless<4.13.0,>=4.9.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.12.0.88)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.0.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (24.2)
# Requirement already satisfied: pynput<1.9.0,>=1.7.7 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (1.8.1)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (3.5)
# Requirement already satisfied: wandb<0.22.0,>=0.20.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.21.4)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (2.7.1)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.22.1)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (1.2.2)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.3) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (3.2.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.3) (2.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.3) (7.1.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.3) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.20.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.9.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.3) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (12.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.3) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.3) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.3) (0.6.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.3) (25.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.3) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.3) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.3) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.3.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (6.33.2)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (2.48.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.3) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.3) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.2.14)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.3-0.editable-py3-none-any.whl size=15676 sha256=52d661a808089fdb50e0b87b92c4981e15e7039e813893503faa143039841586
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sr8905mb/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.3
#     Uninstalling lerobot-0.4.3:
#       Successfully uninstalled lerobot-0.4.3
# Successfully installed lerobot-0.4.3
# python: can't open file '/content/lerobot/src/lerobot/scripts/train.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
from huggingface_hub import snapshot_download
import os

# Download complete dataset
local_dir = snapshot_download(
    repo_id="rkothari3/il_gym_pickup",
    repo_type="dataset",
)

# Verify episodes file exists
episodes_path = os.path.join(local_dir, "meta/episodes/chunk-000/file-000.parquet")
print(f"Episodes file exists: {os.path.exists(episodes_path)}")
print(f"Dataset location: {local_dir}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# meta/episodes/chunk-000/file-000.parquet:   0%|          | 0.00/130k [00:00<?, ?B/s]
# meta/tasks.parquet:   0%|          | 0.00/2.14k [00:00<?, ?B/s]
# data/chunk-000/file-000.parquet:   0%|          | 0.00/32.3k [00:00<?, ?B/s]
# videos/observation.images.front/chunk-00(…):   0%|          | 0.00/472k [00:00<?, ?B/s]
# stats.json: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# info.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# videos/observation.images.wrist/chunk-00(…):   0%|          | 0.00/263k [00:00<?, ?B/s]
# Episodes file exists: True
# Dataset location: /root/.cache/huggingface/hub/datasets--rkothari3--il_gym_pickup/snapshots/100451e8b3b11dcdc1147c0b3d354104280665ba

# %%
import os
import shutil
from pathlib import Path

# Source: where HuggingFace Hub downloaded it
source = "/root/.cache/huggingface/hub/datasets--rkothari3--il_gym_pickup/snapshots/100451e8b3b11dcdc1147c0b3d354104280665ba"

# Target: where LeRobot expects it
target = "/root/.cache/huggingface/lerobot/rkothari3/il_gym_pickup"

# Create parent directories
Path(target).parent.mkdir(parents=True, exist_ok=True)

# Remove existing target if it exists
if os.path.exists(target):
    if os.path.islink(target) or os.path.isdir(target):
        try:
            os.unlink(target) if os.path.islink(target) else shutil.rmtree(target)
        except:
            pass

# Create symlink
os.symlink(source, target)
print(f"✓ Created symlink:")
print(f"  From: {target}")
print(f"  To: {source}")

# Verify episodes file is accessible
episodes_path = os.path.join(target, "meta/episodes/chunk-000/file-000.parquet")
print(f"\n✓ Episodes file accessible: {os.path.exists(episodes_path)}")
# Out:
# ✓ Created symlink:
#   From: /root/.cache/huggingface/lerobot/rkothari3/il_gym_pickup
#   To: /root/.cache/huggingface/hub/datasets--rkothari3--il_gym_pickup/snapshots/100451e8b3b11dcdc1147c0b3d354104280665ba
#
# ✓ Episodes file accessible: True

# %%
# !cd lerobot && python src/lerobot/scripts/lerobot_train.py \
  --dataset.repo_id=rkothari3/il_gym_pickup \
  --policy.type=act \
  --output_dir=outputs/train/act_trial \
  --job_name=my_act_training \
  --policy.device=cuda \
  --policy.push_to_hub=false \
  --batch_size=4 \
  --steps=10000
# Out:
# INFO 2025-12-18 03:56:15 ot_train.py:164 {'batch_size': 4,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'rkothari3/il_gym_pickup',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'my_act_training',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_trial',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': False,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': None,
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 10000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-12-18 03:56:15 ot_train.py:172 Logs will be saved locally.
# INFO 2025-12-18 03:56:15 ot_train.py:184 Creating dataset
# INFO 2025-12-18 03:56:15 ot_train.py:203 Creating policy
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 196MB/s]
# INFO 2025-12-18 03:56:17 ot_train.py:248 Creating optimizer and scheduler
# INFO 2025-12-18 03:56:17 ot_train.py:260 Output dir: outputs/train/act_trial
# INFO 2025-12-18 03:56:17 ot_train.py:267 cfg.steps=10000 (10K)
# INFO 2025-12-18 03:56:17 ot_train.py:268 dataset.num_frames=348 (348)
# INFO 2025-12-18 03:56:17 ot_train.py:269 dataset.num_episodes=7
# INFO 2025-12-18 03:56:17 ot_train.py:272 Effective batch size: 4 x 1 = 4
# INFO 2025-12-18 03:56:17 ot_train.py:273 num_learnable_params=51607428 (52M)
# INFO 2025-12-18 03:56:17 ot_train.py:274 num_total_params=51607428 (52M)
# /usr/local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO 2025-12-18 03:56:17 ot_train.py:330 Start offline training on a fixed dataset
# INFO 2025-12-18 03:56:40 ot_train.py:357 step:200 smpl:800 ep:16 epch:2.30 loss:6.252 grdn:203.062 lr:1.0e-05 updt_s:0.099 data_s:0.015
# INFO 2025-12-18 03:56:59 ot_train.py:357 step:400 smpl:2K ep:32 epch:4.60 loss:2.895 grdn:120.747 lr:1.0e-05 updt_s:0.086 data_s:0.009
# INFO 2025-12-18 03:57:19 ot_train.py:357 step:600 smpl:2K ep:48 epch:6.90 loss:2.409 grdn:104.068 lr:1.0e-05 updt_s:0.089 data_s:0.010
# INFO 2025-12-18 03:57:39 ot_train.py:357 step:800 smpl:3K ep:64 epch:9.20 loss:2.194 grdn:96.944 lr:1.0e-05 updt_s:0.088 data_s:0.012
# INFO 2025-12-18 03:57:59 ot_train.py:357 step:1K smpl:4K ep:80 epch:11.49 loss:2.005 grdn:91.799 lr:1.0e-05 updt_s:0.089 data_s:0.009
# INFO 2025-12-18 03:58:19 ot_train.py:357 step:1K smpl:5K ep:97 epch:13.79 loss:1.802 grdn:84.858 lr:1.0e-05 updt_s:0.091 data_s:0.009
# INFO 2025-12-18 03:58:39 ot_train.py:357 step:1K smpl:6K ep:113 epch:16.09 loss:1.702 grdn:83.005 lr:1.0e-05 updt_s:0.087 data_s:0.013
# INFO 2025-12-18 03:58:59 ot_train.py:357 step:2K smpl:6K ep:129 epch:18.39 loss:1.569 grdn:79.741 lr:1.0e-05 updt_s:0.089 data_s:0.011
# INFO 2025-12-18 03:59:18 ot_train.py:357 step:2K smpl:7K ep:145 epch:20.69 loss:1.484 grdn:76.478 lr:1.0e-05 updt_s:0.088 data_s:0.009
# INFO 2025-12-18 03:59:38 ot_train.py:357 step:2K smpl:8K ep:161 epch:22.99 loss:1.372 grdn:72.514 lr:1.0e-05 updt_s:0.088 data_s:0.011
# INFO 2025-12-18 03:59:59 ot_train.py:357 step:2K smpl:9K ep:177 epch:25.29 loss:1.277 grdn:69.934 lr:1.0e-05 updt_s:0.088 data_s:0.014
# INFO 2025-12-18 04:00:19 ot_train.py:357 step:2K smpl:10K ep:193 epch:27.59 loss:1.204 grdn:67.092 lr:1.0e-05 updt_s:0.091 data_s:0.009
# INFO 2025-12-18 04:00:39 ot_train.py:357 step:3K smpl:10K ep:209 epch:29.89 loss:1.101 grdn:64.904 lr:1.0e-05 updt_s:0.091 data_s:0.009
# INFO 2025-12-18 04:01:00 ot_train.py:357 step:3K smpl:11K ep:225 epch:32.18 loss:1.039 grdn:62.552 lr:1.0e-05 updt_s:0.088 data_s:0.014
# INFO 2025-12-18 04:01:20 ot_train.py:357 step:3K smpl:12K ep:241 epch:34.48 loss:0.957 grdn:59.117 lr:1.0e-05 updt_s:0.090 data_s:0.011
# INFO 2025-12-18 04:01:39 ot_train.py:357 step:3K smpl:13K ep:257 epch:36.78 loss:0.902 grdn:57.356 lr:1.0e-05 updt_s:0.088 data_s:0.009
# INFO 2025-12-18 04:02:00 ot_train.py:357 step:3K smpl:14K ep:274 epch:39.08 loss:0.819 grdn:53.590 lr:1.0e-05 updt_s:0.089 data_s:0.015
# INFO 2025-12-18 04:02:21 ot_train.py:357 step:4K smpl:14K ep:290 epch:41.38 loss:0.759 grdn:52.023 lr:1.0e-05 updt_s:0.092 data_s:0.008
# INFO 2025-12-18 04:02:40 ot_train.py:357 step:4K smpl:15K ep:306 epch:43.68 loss:0.711 grdn:50.522 lr:1.0e-05 updt_s:0.088 data_s:0.009
# INFO 2025-12-18 04:03:00 ot_train.py:357 step:4K smpl:16K ep:322 epch:45.98 loss:0.657 grdn:47.693 lr:1.0e-05 updt_s:0.091 data_s:0.009
# INFO 2025-12-18 04:03:20 ot_train.py:357 step:4K smpl:17K ep:338 epch:48.28 loss:0.611 grdn:46.722 lr:1.0e-05 updt_s:0.088 data_s:0.013
# INFO 2025-12-18 04:03:41 ot_train.py:357 step:4K smpl:18K ep:354 epch:50.57 loss:0.572 grdn:44.465 lr:1.0e-05 updt_s:0.089 data_s:0.011
# INFO 2025-12-18 04:04:00 ot_train.py:357 step:5K smpl:18K ep:370 epch:52.87 loss:0.533 grdn:42.336 lr:1.0e-05 updt_s:0.088 data_s:0.009
# INFO 2025-12-18 04:04:21 ot_train.py:357 step:5K smpl:19K ep:386 epch:55.17 loss:0.488 grdn:40.541 lr:1.0e-05 updt_s:0.088 data_s:0.015
# INFO 2025-12-18 04:04:42 ot_train.py:357 step:5K smpl:20K ep:402 epch:57.47 loss:0.455 grdn:39.051 lr:1.0e-05 updt_s:0.092 data_s:0.011
# INFO 2025-12-18 04:05:02 ot_train.py:357 step:5K smpl:21K ep:418 epch:59.77 loss:0.437 grdn:38.052 lr:1.0e-05 updt_s:0.094 data_s:0.010
# INFO 2025-12-18 04:05:24 ot_train.py:357 step:5K smpl:22K ep:434 epch:62.07 loss:0.403 grdn:36.163 lr:1.0e-05 updt_s:0.090 data_s:0.017
# INFO 2025-12-18 04:05:44 ot_train.py:357 step:6K smpl:22K ep:451 epch:64.37 loss:0.376 grdn:34.474 lr:1.0e-05 updt_s:0.090 data_s:0.009
# INFO 2025-12-18 04:06:03 ot_train.py:357 step:6K smpl:23K ep:467 epch:66.67 loss:0.358 grdn:33.651 lr:1.0e-05 updt_s:0.089 data_s:0.009
# INFO 2025-12-18 04:06:24 ot_train.py:357 step:6K smpl:24K ep:483 epch:68.97 loss:0.337 grdn:32.109 lr:1.0e-05 updt_s:0.092 data_s:0.010
# INFO 2025-12-18 04:06:46 ot_train.py:357 step:6K smpl:25K ep:499 epch:71.26 loss:0.320 grdn:31.154 lr:1.0e-05 updt_s:0.094 data_s:0.015
# INFO 2025-12-18 04:07:07 ot_train.py:357 step:6K smpl:26K ep:515 epch:73.56 loss:0.300 grdn:30.356 lr:1.0e-05 updt_s:0.092 data_s:0.013
# INFO 2025-12-18 04:07:29 ot_train.py:357 step:7K smpl:26K ep:531 epch:75.86 loss:0.285 grdn:29.194 lr:1.0e-05 updt_s:0.091 data_s:0.019
# INFO 2025-12-18 04:07:49 ot_train.py:357 step:7K smpl:27K ep:547 epch:78.16 loss:0.276 grdn:28.746 lr:1.0e-05 updt_s:0.087 data_s:0.013
# INFO 2025-12-18 04:08:09 ot_train.py:357 step:7K smpl:28K ep:563 epch:80.46 loss:0.266 grdn:27.609 lr:1.0e-05 updt_s:0.092 data_s:0.009
# INFO 2025-12-18 04:08:29 ot_train.py:357 step:7K smpl:29K ep:579 epch:82.76 loss:0.245 grdn:26.138 lr:1.0e-05 updt_s:0.092 data_s:0.010
# INFO 2025-12-18 04:08:50 ot_train.py:357 step:7K smpl:30K ep:595 epch:85.06 loss:0.237 grdn:26.177 lr:1.0e-05 updt_s:0.085 data_s:0.016
# INFO 2025-12-18 04:09:10 ot_train.py:357 step:8K smpl:30K ep:611 epch:87.36 loss:0.229 grdn:25.485 lr:1.0e-05 updt_s:0.091 data_s:0.010
# INFO 2025-12-18 04:09:30 ot_train.py:357 step:8K smpl:31K ep:628 epch:89.66 loss:0.224 grdn:24.703 lr:1.0e-05 updt_s:0.089 data_s:0.009
# INFO 2025-12-18 04:09:50 ot_train.py:357 step:8K smpl:32K ep:644 epch:91.95 loss:0.217 grdn:24.369 lr:1.0e-05 updt_s:0.090 data_s:0.009
# INFO 2025-12-18 04:10:11 ot_train.py:357 step:8K smpl:33K ep:660 epch:94.25 loss:0.211 grdn:23.823 lr:1.0e-05 updt_s:0.090 data_s:0.016
# INFO 2025-12-18 04:10:30 ot_train.py:357 step:8K smpl:34K ep:676 epch:96.55 loss:0.206 grdn:23.474 lr:1.0e-05 updt_s:0.089 data_s:0.009
# INFO 2025-12-18 04:10:51 ot_train.py:357 step:9K smpl:34K ep:692 epch:98.85 loss:0.202 grdn:23.180 lr:1.0e-05 updt_s:0.089 data_s:0.011
# INFO 2025-12-18 04:11:11 ot_train.py:357 step:9K smpl:35K ep:708 epch:101.15 loss:0.190 grdn:21.896 lr:1.0e-05 updt_s:0.087 data_s:0.015
# INFO 2025-12-18 04:11:31 ot_train.py:357 step:9K smpl:36K ep:724 epch:103.45 loss:0.187 grdn:21.776 lr:1.0e-05 updt_s:0.092 data_s:0.009
# INFO 2025-12-18 04:11:51 ot_train.py:357 step:9K smpl:37K ep:740 epch:105.75 loss:0.180 grdn:20.862 lr:1.0e-05 updt_s:0.090 data_s:0.009
# INFO 2025-12-18 04:12:12 ot_train.py:357 step:9K smpl:38K ep:756 epch:108.05 loss:0.178 grdn:20.906 lr:1.0e-05 updt_s:0.087 data_s:0.015
# INFO 2025-12-18 04:12:32 ot_train.py:357 step:10K smpl:38K ep:772 epch:110.34 loss:0.178 grdn:21.217 lr:1.0e-05 updt_s:0.090 data_s:0.011
# INFO 2025-12-18 04:12:52 ot_train.py:357 step:10K smpl:39K ep:789 epch:112.64 loss:0.170 grdn:20.374 lr:1.0e-05 updt_s:0.088 data_s:0.009
# INFO 2025-12-18 04:13:12 ot_train.py:357 step:10K smpl:40K ep:805 epch:114.94 loss:0.169 grdn:20.325 lr:1.0e-05 updt_s:0.090 data_s:0.011
# INFO 2025-12-18 04:13:12 ot_train.py:367 Checkpoint policy after step 10000
# INFO 2025-12-18 04:13:16 ot_train.py:438 End of training

# %%
# View model train files
import os

# List checkpoint directory
checkpoint_dir = "lerobot/outputs/train/act_trial/checkpoints/last/pretrained_model"
for file in os.listdir(checkpoint_dir):
    file_path = os.path.join(checkpoint_dir, file)
    size_mb = os.path.getsize(file_path) / (1024*1024)
    print(f"{file}: {size_mb:.2f} MB")
# Out:
# policy_preprocessor.json: 0.00 MB
# config.json: 0.00 MB
# policy_preprocessor_step_3_normalizer_processor.safetensors: 0.01 MB
# policy_postprocessor_step_0_unnormalizer_processor.safetensors: 0.01 MB
# policy_postprocessor.json: 0.00 MB
# model.safetensors: 197.16 MB
# train_config.json: 0.01 MB

# %%
# Check training logs
# View final training metrics
import json

config_path = "lerobot/outputs/train/act_trial/checkpoints/last/pretrained_model/train_config.json"
with open(config_path) as f:
    config = json.load(f)

print("Training completed:")
print(f"  Steps: {config.get('steps', 'N/A')}")
print(f"  Batch size: {config.get('batch_size', 'N/A')}")
# Out:
# Training completed:
#   Steps: 10000
#   Batch size: 4

# %%
import json

eval_config = {
    "env": {
        "type": "gym_manipulator",
        "name": "gym_hil",
        "task": "PandaPickCubeKeyboard-v0",  # Or use Gamepad-v0 if you have a gamepad
        "fps": 10
    },
    "dataset": {
        "repo_id": "rkothari3/il_gym_pickup",
        "dataset_root": None,
        "task": "pick_cube"
    },
    "pretrained_policy_name_or_path": "rkothari3/act_gym_pickup",
    "device": "cuda"
}

# Save to file
with open('/content/lerobot/eval_config.json', 'w') as f:
    json.dump(eval_config, f, indent=2)

print("✅ Eval config saved to eval_config.json")
# Out:
# ✅ Eval config saved to eval_config.json

# %%
# !cd lerobot && python src/lerobot/scripts/lerobot_eval.py \
    --policy.path=rkothari3/act_gym_pickup \
    --env.type=gym_manipulator \
    --env.task=gym_hil/PandaPickCubeKeyboard-v0 \
    --eval.n_episodes=10 \
    --eval.batch_size=10 \
    --eval.use_async_envs=false \
    --policy.device=cuda
# Out:
# WARNING 2025-12-18 04:40:07 figs/eval.py:63 No job name provided, using 'gym_manipulator_act' as job name.
# INFO 2025-12-18 04:40:07 bot_eval.py:500 {'env': {'disable_env_checker': True,
#          'features': {},
#          'features_map': {},
#          'fps': 30,
#          'max_parallel_tasks': 1,
#          'name': 'real_robot',
#          'processor': {'control_mode': 'gamepad',
#                        'gripper': None,
#                        'image_preprocessing': None,
#                        'inverse_kinematics': None,
#                        'max_gripper_pos': 100.0,
#                        'observation': None,
#                        'reset': None,
#                        'reward_classifier': None},
#          'robot': None,
#          'task': 'gym_hil/PandaPickCubeKeyboard-v0',
#          'teleop': None},
#  'eval': {'batch_size': 10, 'n_episodes': 10, 'use_async_envs': False},
#  'job_name': 'gym_manipulator_act',
#  'output_dir': PosixPath('outputs/eval/2025-12-18/04-40-07_gym_manipulator_act'),
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {'observation.images.front': {'shape': (3,
#                                                                       128,
#                                                                       128),
#                                                             'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.images.wrist': {'shape': (3,
#                                                                       128,
#                                                                       128),
#                                                             'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.state': {'shape': (18,),
#                                                      'type': <FeatureType.STATE: 'STATE'>}},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {'action': {'shape': (4,),
#                                            'type': <FeatureType.ACTION: 'ACTION'>}},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': PosixPath('rkothari3/act_gym_pickup'),
#             'private': None,
#             'push_to_hub': False,
#             'replace_final_stride_with_dilation': 0,
#             'repo_id': None,
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'seed': 1000}
# INFO 2025-12-18 04:40:07 bot_eval.py:509 Output dir: outputs/eval/2025-12-18/04-40-07_gym_manipulator_act
# INFO 2025-12-18 04:40:07 bot_eval.py:511 Making environment.
# gym id 'gym_gym_manipulator/gym_hil/PandaPickCubeKeyboard-v0' not found, attempting to import 'gym_gym_manipulator'...
# Traceback (most recent call last):
#   File "/content/lerobot/src/lerobot/envs/factory.py", line 165, in make_env
#     importlib.import_module(cfg.package_name)
#   File "/usr/local/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'gym_gym_manipulator'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/lerobot/src/lerobot/scripts/lerobot_eval.py", line 801, in <module>
#     main()
#   File "/content/lerobot/src/lerobot/scripts/lerobot_eval.py", line 797, in main
#     eval_main()
#   File "/content/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot/src/lerobot/scripts/lerobot_eval.py", line 512, in eval_main
#     envs = make_env(cfg.env, n_envs=cfg.eval.batch_size, use_async_envs=cfg.eval.use_async_envs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot/src/lerobot/envs/factory.py", line 167, in make_env
#     raise ModuleNotFoundError(
# ModuleNotFoundError: Package 'gym_gym_manipulator' required for env 'gym_manipulator' not found. Please install it or check PYTHONPATH.

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `Robot Arm` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Robot Arm`

# %%
from huggingface_hub import HfApi

api = HfApi()

# Upload the entire pretrained_model directory
api.upload_folder(
    folder_path="lerobot/outputs/train/act_trial/checkpoints/last/pretrained_model",
    repo_id="rkothari3/act_gym_pickup",
    repo_type="model",
    commit_message="Upload trained ACT policy"
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     401     try:
# --> 402         response.raise_for_status()
#     403     except HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/rkothari3/act_gym_pickup/preupload/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# /tmp/ipython-input-802921257.py in <cell line: 0>()
#       4
#       5 # Upload the entire pretrained_model directory
# ----> 6 api.upload_folder(
#       7     folder_path="lerobot/outputs/train/act_trial/checkpoints/last/pretrained_model",
#       8     repo_id="rkothari3/act_gym_pickup",
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in _inner(self, *args, **kwargs)
#    1685
#    1686         # Otherwise, call the function normally
# -> 1687         return fn(self, *args, **kwargs)
#    1688
#    1689     _inner.is_future_compatible = True  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in upload_folder(self, repo_id, folder_path, path_in_repo, commit_message, commit_description, token, repo_type, revision, create_pr, parent_commit, allow_patterns, ignore_patterns, delete_patterns, run_as_future)
#    4928         commit_message = commit_message or "Upload folder using huggingface_hub"
#    4929
# -> 4930         commit_info = self.create_commit(
#    4931             repo_type=repo_type,
#    4932             repo_id=repo_id,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in _inner(self, *args, **kwargs)
#    1685
#    1686         # Otherwise, call the function normally
# -> 1687         return fn(self, *args, **kwargs)
#    1688
#    1689     _inner.is_future_compatible = True  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in create_commit(self, repo_id, operations, commit_message, commit_description, token, repo_type, revision, create_pr, num_threads, parent_commit, run_as_future)
#    4227         _warn_on_overwriting_operations(operations)
#    4228
# -> 4229         self.preupload_lfs_files(
#    4230             repo_id=repo_id,
#    4231             additions=additions,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in preupload_lfs_files(self, repo_id, additions, token, repo_type, revision, create_pr, num_threads, free_memory, gitignore_content)
#    4447         if len(additions_no_upload_mode) > 0:
#    4448             try:
# -> 4449                 _fetch_upload_modes(
#    4450                     additions=additions_no_upload_mode,
#    4451                     repo_type=repo_type,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/_commit_api.py in _fetch_upload_modes(additions, repo_type, repo_id, headers, revision, endpoint, create_pr, gitignore_content)
#     750             params={"create_pr": "1"} if create_pr else None,
#     751         )
# --> 752         hf_raise_for_status(resp)
#     753         preupload_info = _validate_preupload_info(resp.json())
#     754         upload_modes.update(**{file["path"]: file["uploadMode"] for file in preupload_info["files"]})
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     450                 " https://huggingface.co/docs/huggingface_hub/authentication"
#     451             )
# --> 452             raise _format(RepositoryNotFoundError, message, response) from e
#     453
#     454         elif response.status_code == 400:
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-6943822f-38b76b01424c1d947cc17d28;4f618525-3884-4788-863a-f36a17059d56)
#
# Repository Not Found for url: https://huggingface.co/api/models/rkothari3/act_gym_pickup/preupload/main.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Note: Creating a commit assumes that the repo already exists on the Huggingface Hub. Please use `create_repo` if it's not the case.

# %%
# !huggingface-cli upload rkothari3/act_gym_pickup \
    /content/lerobot/outputs/train/act_trial/checkpoints/last/pretrained_model
# Out:
# ⚠️  Warning: 'huggingface-cli upload' is deprecated. Use 'hf upload' instead.
# Start hashing 7 files.
# Finished hashing 7 files.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...d_model/model.safetensors:   0% 564k/207M [00:00<?, ?B/s]
#
# Processing Files (0 / 1)      :   0% 564k/207M [00:01<08:33, 401kB/s,  470kB/s  ]
# New Data Upload               :   1% 564k/67.1M [00:01<02:45, 401kB/s,  470kB/s  ]
#
# Processing Files (0 / 1)      :   2% 5.07M/207M [00:01<00:48, 4.14MB/s, 3.62MB/s  ]
# New Data Upload               :   8% 5.07M/67.1M [00:01<00:14, 4.14MB/s, 3.62MB/s  ]
#
# Processing Files (0 / 1)      :   7% 14.1M/207M [00:01<00:15, 12.1MB/s, 8.81MB/s  ]
# New Data Upload               :  11% 14.1M/134M [00:01<00:09, 12.1MB/s, 8.81MB/s  ]
#
# Processing Files (0 / 1)      :  12% 24.2M/207M [00:02<00:08, 20.5MB/s, 13.4MB/s  ]
# New Data Upload               :  18% 24.2M/134M [00:02<00:05, 20.5MB/s, 13.4MB/s  ]
#
# Processing Files (0 / 1)      :  18% 36.6M/207M [00:02<00:05, 30.4MB/s, 18.3MB/s  ]
# New Data Upload               :  27% 36.6M/134M [00:02<00:03, 30.4MB/s, 18.3MB/s  ]
#
# Processing Files (0 / 1)      :  24% 49.6M/207M [00:02<00:04, 38.9MB/s, 22.5MB/s  ]
# New Data Upload               :  37% 49.6M/134M [00:02<00:02, 39.0MB/s, 22.5MB/s  ]
#
# Processing Files (0 / 1)      :  31% 64.8M/207M [00:02<00:02, 48.7MB/s, 27.0MB/s  ]
# New Data Upload               :  32% 64.8M/201M [00:02<00:02, 48.7MB/s, 27.0MB/s  ]
#
# Processing Files (0 / 1)      :  36% 73.8M/207M [00:02<00:02, 47.9MB/s, 28.4MB/s  ]
# New Data Upload               :  36% 73.8M/207M [00:02<00:02, 47.9MB/s, 28.4MB/s  ]
#
#
#   ...zer_processor.safetensors:  10% 1.05k/10.4k [00:00<?, ?B/s]
#
#
#
#   ...zer_processor.safetensors:  10% 1.05k/10.4k [00:00<?, ?B/s]
#
#   ...d_model/model.safetensors:  37% 76.5M/207M [00:01<00:02, 47.5MB/s]
#
#
#   ...zer_processor.safetensors:  10% 1.05k/10.4k [00:00<?, ?B/s]
#
#
#
# Processing Files (0 / 3)      :  37% 76.5M/207M [00:03<00:03, 38.3MB/s, 27.3MB/s  ]
# New Data Upload               :  37% 76.5M/207M [00:03<00:03, 38.3MB/s, 27.3MB/s  ]
#
#   ...d_model/model.safetensors:  41% 83.8M/207M [00:01<00:02, 46.2MB/s]
#
#
#   ...zer_processor.safetensors:  20% 2.10k/10.4k [00:00<00:01, 5.25kB/s]
#
#
#
# Processing Files (0 / 3)      :  41% 83.8M/207M [00:03<00:03, 37.7MB/s, 27.9MB/s  ]
# New Data Upload               :  41% 83.8M/207M [00:03<00:03, 37.7MB/s, 27.9MB/s  ]
#
#   ...d_model/model.safetensors:  47% 97.8M/207M [00:02<00:02, 48.6MB/s]
#
#
#   ...zer_processor.safetensors:  91% 9.46k/10.4k [00:00<00:00, 21.0kB/s]
#
#
#
# Processing Files (0 / 3)      :  47% 97.8M/207M [00:03<00:02, 47.1MB/s, 30.6MB/s  ]
# New Data Upload               :  47% 97.8M/207M [00:03<00:02, 47.1MB/s, 30.6MB/s  ]
#
#   ...d_model/model.safetensors:  54% 112M/207M [00:02<00:01, 50.8MB/s]
#
#
#   ...zer_processor.safetensors:  91% 9.46k/10.4k [00:00<00:00, 14.0kB/s]
#
#
#
# Processing Files (0 / 3)      :  54% 112M/207M [00:03<00:01, 54.6MB/s, 33.0MB/s  ]
# New Data Upload               :  54% 112M/207M [00:03<00:01, 54.6MB/s, 33.0MB/s  ]
#
#   ...d_model/model.safetensors:  61% 126M/207M [00:02<00:01, 52.4MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:00<00:00, 11.7kB/s]
#
#
#
# Processing Files (2 / 3)      :  61% 126M/207M [00:03<00:01, 59.0MB/s, 35.1MB/s  ]
# New Data Upload               :  61% 126M/207M [00:03<00:01, 59.0MB/s, 35.1MB/s  ]
#
#   ...d_model/model.safetensors:  69% 142M/207M [00:02<00:01, 54.6MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:01<00:00, 9.40kB/s]
#
#
#
# Processing Files (2 / 3)      :  69% 142M/207M [00:04<00:00, 65.5MB/s, 37.5MB/s  ]
# New Data Upload               :  69% 142M/207M [00:04<00:00, 65.5MB/s, 37.5MB/s  ]
#
#   ...d_model/model.safetensors:  77% 159M/207M [00:02<00:00, 56.6MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:01<00:00, 7.83kB/s]
#
#
#
# Processing Files (2 / 3)      :  77% 159M/207M [00:04<00:00, 71.0MB/s, 39.8MB/s  ]
# New Data Upload               :  77% 159M/207M [00:04<00:00, 71.0MB/s, 39.8MB/s  ]
#
#   ...d_model/model.safetensors:  85% 175M/207M [00:03<00:00, 58.1MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:01<00:00, 6.71kB/s]
#
#
#
# Processing Files (2 / 3)      :  85% 175M/207M [00:04<00:00, 73.0MB/s, 41.6MB/s  ]
# New Data Upload               :  85% 175M/207M [00:04<00:00, 73.0MB/s, 41.6MB/s  ]
#
#   ...d_model/model.safetensors:  91% 188M/207M [00:03<00:00, 58.4MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:01<00:00, 5.87kB/s]
#
#
#
# Processing Files (2 / 3)      :  91% 188M/207M [00:04<00:00, 70.4MB/s, 42.6MB/s  ]
# New Data Upload               :  91% 188M/207M [00:04<00:00, 70.4MB/s, 42.6MB/s  ]
#
#   ...d_model/model.safetensors:  95% 195M/207M [00:03<00:00, 57.3MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:01<00:00, 5.22kB/s]
#
#
#
# Processing Files (2 / 3)      :  95% 195M/207M [00:04<00:00, 61.0MB/s, 42.5MB/s  ]
# New Data Upload               :  95% 195M/207M [00:04<00:00, 61.0MB/s, 42.5MB/s  ]
#
#   ...d_model/model.safetensors:  99% 205M/207M [00:03<00:00, 56.7MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 4.70kB/s]
#
#
#
# Processing Files (2 / 3)      :  99% 205M/207M [00:05<00:00, 56.9MB/s, 42.7MB/s  ]
# New Data Upload               :  99% 205M/207M [00:05<00:00, 56.9MB/s, 42.7MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:03<00:00, 54.2MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 4.27kB/s]
#
#
#
# Processing Files (2 / 3)      : 100% 207M/207M [00:05<00:00, 42.4MB/s, 41.3MB/s  ]
# New Data Upload               : 100% 207M/207M [00:05<00:00, 42.4MB/s, 41.3MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 51.5MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.91kB/s]
#
#
#
# Processing Files (2 / 3)      : 100% 207M/207M [00:05<00:00, 29.7MB/s, 39.7MB/s  ]
# New Data Upload               : 100% 207M/207M [00:05<00:00, 29.7MB/s, 39.7MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 49.0MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.61kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.61kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 46.8MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.36kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.36kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 44.8MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.13kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:02<00:00, 3.13kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 43.0MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.94kB/s]
#
#
#
# Processing Files (3 / 3)      : 100% 207M/207M [00:06<00:00, 11.1MB/s, 34.5MB/s  ]
# New Data Upload               : 100% 207M/207M [00:06<00:00, 11.1MB/s, 34.5MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:05<00:00, 41.2MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.76kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.76kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:05<00:00, 41.1MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.75kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.75kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:05<00:00, 39.6MB/s]
#
#
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.61kB/s]
#
#
#
# Processing Files (3 / 3)      : 100% 207M/207M [00:06<00:00, 31.3MB/s, 32.3MB/s  ]
# New Data Upload               : 100% 207M/207M [00:06<00:00, 31.3MB/s, 32.3MB/s  ]
#   ...d_model/model.safetensors: 100% 207M/207M [00:05<00:00, 39.6MB/s]
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.61kB/s]
#   ...zer_processor.safetensors: 100% 10.4k/10.4k [00:03<00:00, 2.61kB/s]
# https://huggingface.co/rkothari3/act_gym_pickup/tree/main/.
